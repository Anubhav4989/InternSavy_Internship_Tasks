# %% [markdown]
# <a href="https://colab.research.google.com/github/Anubhav4989/InternSavy_Internship_Tasks/blob/main/Anubhav_Kumar_Tiwary_Task_3_Data_Science_Intern_InternSavy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# TASK 3: Customer Segmentation Analysis
# with Python.

# %% [markdown]
# Data set link: https://www.kaggle.com/datasets/vjchoudhary7/customer-segmentation-tutorial-in-python

# %% [markdown]
# #**SegmentShift: Shifting Gears in Customer Analysis with Python**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings("ignore")

# %%
# Mount Google Drive to access the dataset
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df = pd.read_csv("/content/drive/MyDrive/Mall_Customers.csv")

# %%
df.head()
# Out:
#    CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40

# %%
df.drop(columns='CustomerID', inplace=True)

# %%
df.shape
# Out:
# (200, 4)

# %%
df.sample(10)
# Out:
#      Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 175  Female   30                  88                      86
# 149    Male   34                  78                      90
# 136  Female   44                  73                       7
# 154  Female   47                  78                      16
# 150    Male   43                  78                      17
# 90   Female   68                  59                      55
# 173    Male   36                  87                      92
# 114  Female   18                  65                      48
# 88   Female   34                  58                      60
# 198    Male   32                 137                      18

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 4 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Gender                  200 non-null    object
#  1   Age                     200 non-null    int64
#  2   Annual Income (k$)      200 non-null    int64
#  3   Spending Score (1-100)  200 non-null    int64
# dtypes: int64(3), object(1)
# memory usage: 6.4+ KB

# %%
df.isnull().sum()
# Out:
# Gender                    0
# Age                       0
# Annual Income (k$)        0
# Spending Score (1-100)    0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.columns
# Out:
# Index(['Gender', 'Age', 'Annual Income (k$)', 'Spending Score (1-100)'], dtype='object')

# %%
df.describe().T
# Out:
#                         count   mean        std   min    25%   50%   75%  \
# Age                     200.0  38.85  13.969007  18.0  28.75  36.0  49.0
# Annual Income (k$)      200.0  60.56  26.264721  15.0  41.50  61.5  78.0
# Spending Score (1-100)  200.0  50.20  25.823522   1.0  34.75  50.0  73.0
#
#                           max
# Age                      70.0
# Annual Income (k$)      137.0
# Spending Score (1-100)   99.0

# %%
df.Gender.value_counts()
# Out:
# Female    112
# Male       88
# Name: Gender, dtype: int64

# %%
df.Gender.value_counts().plot(kind='pie', autopct='%1.0f%%', title="Genre PieChart", figsize=(8,6))
plt.show()

# %%
df.Gender.value_counts().plot(kind='bar', title="Genre PieChart", figsize=(8,6))
plt.show()

# %%
df.Age.plot(kind='kde',figsize=(8,6), title="AGE Distribution Plot")
plt.show()

# %%
df.Age.plot(kind='box',figsize=(8,6), title="AGE BoxPlot")
plt.show()

# %%
df['Annual Income (k$)'].max()
# Out:
# 137

# %%
df['Annual Income (k$)'].min()
# Out:
# 15

# %%
df['Annual Income (k$)'].plot(kind='kde', figsize=(8,6), title="Annual Income Distribution Plot")
plt.show()

# %%
df['Annual Income (k$)'].plot(kind='box', figsize=(8,6), title="Annual Income BoxPlot")
plt.show()

# %%
df = df[df['Annual Income (k$)']<120]

# %%
df.shape
# Out:
# (194, 4)

# %%
df.head()
# Out:
#    Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0    Male   19                  15                      39
# 1    Male   21                  15                      81
# 2  Female   20                  16                       6
# 3  Female   23                  16                      77
# 4  Female   31                  17                      40

# %%
df['Annual Income (k$)'].plot(kind='box', figsize=(8,6), title="Annual Income BoxPlot")
plt.show()

# %%
df['Spending Score (1-100)'].plot(kind='kde', figsize=(8,6), title="Spending Score Distribution")
plt.show()

# %%
df['Spending Score (1-100)'].plot(kind='box', figsize=(8,6), title="Spending Score BoxPlot")
plt.show()

# %% [markdown]
# ## BiVariant Analysis

# %%
df.head()
# Out:
#    Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0    Male   19                  15                      39
# 1    Male   21                  15                      81
# 2  Female   20                  16                       6
# 3  Female   23                  16                      77
# 4  Female   31                  17                      40

# %%
df.plot(kind='scatter' ,x='Age',y='Annual Income (k$)')
plt.show()

# %%
plt.figure(figsize=(9,6))
sns.scatterplot(x='Age', y='Annual Income (k$)', hue='Gender', data=df)
plt.show()

# %%
df.plot(kind='scatter' ,x='Age',y='Spending Score (1-100)')
plt.show()

# %%
plt.figure(figsize=(9,6))
sns.scatterplot(x='Age', y='Spending Score (1-100)', hue='Gender', data=df)
plt.show()

# %%
df.plot(kind='scatter' ,x='Gender',y='Annual Income (k$)')
plt.show()

# %%
df.plot(kind='scatter' ,x='Gender',y='Spending Score (1-100)')
plt.show()

# %% [markdown]
# ## Multi-Variant Analysis

# %%
import plotly.express as px

fig = px.scatter_3d(df, x='Age', y='Annual Income (k$)', z='Spending Score (1-100)', color='Gender')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
